# %% [markdown]
# # Analysing Global Power Plant Database (Puerto Rico)
# ## Update: 30/10/2020

# %%
## Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use("seaborn-pastel")

# Plotting geographical data
import folium
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# Total power plants in Puerto Rico
df_power_plants = pd.read_csv('https://raw.githubusercontent.com/dnzengou/my-green-recommender/main/data/gppd_120_pr.csv')
df_power_plants.head().T
# Out:
#                                                                           0  \
# system:index                                           0000000000000000315a
# capacity_mw                                                              15
# commissioning_year                                                     1942
# country                                                                 USA
# country_long                                       United States of America
# estimated_generation_gwh                                            685.398
# generation_gwh_2013                                                       0
# generation_gwh_2014                                                       0
# generation_gwh_2015                                                       0
# generation_gwh_2016                                                       0
# generation_gwh_2017                                                       0
# geolocation_source                                                      WRI
# gppd_idnr                                                        WRI1026827
# name                                                              Dos Bocas
# other_fuel1                                                             NaN
# other_fuel2                                                             NaN
# other_fuel3                                                             NaN
# owner                                                                 PREPA
# primary_fuel                                                          Hydro
# source                                                                 CEPR
# url                                    http://energia.pr.gov/datos/plantas/
# wepp_id                                                               30936
# year_of_capacity_data                                                     0
# .geo                      {"type":"Point","coordinates":[-66.66629863706...
#
#                                                                           1  \
# system:index                                           000000000000000026e5
# capacity_mw                                                            1492
# commissioning_year                                                     1975
# country                                                                 USA
# country_long                                       United States of America
# estimated_generation_gwh                                            8334.01
# generation_gwh_2013                                                       0
# generation_gwh_2014                                                       0
# generation_gwh_2015                                                       0
# generation_gwh_2016                                                       0
# generation_gwh_2017                                                       0
# geolocation_source                                                      WRI
# gppd_idnr                                                        WRI1026809
# name                                                                Aguirre
# other_fuel1                                                             NaN
# other_fuel2                                                             NaN
# other_fuel3                                                             NaN
# owner                                                                 PREPA
# primary_fuel                                                            Oil
# source                                                                PREPA
# url                                        http://www.prepa.com/aguirre.asp
# wepp_id                                                               30928
# year_of_capacity_data                                                     0
# .geo                      {"type":"Point","coordinates":[-66.23079607357...
#
#                                                                           2  \
# system:index                                           00000000000000002fda
# capacity_mw                                                             990
# commissioning_year                                                     1962
# country                                                                 USA
# country_long                                       United States of America
# estimated_generation_gwh                                            5529.94
# generation_gwh_2013                                                       0
# generation_gwh_2014                                                       0
# generation_gwh_2015                                                       0
# generation_gwh_2016                                                       0
# generation_gwh_2017                                                       0
# geolocation_source                                                      WRI
# gppd_idnr                                                        WRI1026811
# name                                                              Costa Sur
# other_fuel1                                                             NaN
# other_fuel2                                                             NaN
# other_fuel3                                                             NaN
# owner                                                                 PREPA
# primary_fuel                                                            Oil
# source                                                                PREPA
# url                                       http://www.prepa.com/costasur.asp
# wepp_id                                                               30934
# year_of_capacity_data                                                     0
# .geo                      {"type":"Point","coordinates":[-66.75340271704...
#
#                                                                           3  \
# system:index                                           00000000000000003f76
# capacity_mw                                                             602
# commissioning_year                                                     1960
# country                                                                 USA
# country_long                                       United States of America
# estimated_generation_gwh                                            3362.65
# generation_gwh_2013                                                       0
# generation_gwh_2014                                                       0
# generation_gwh_2015                                                       0
# generation_gwh_2016                                                       0
# generation_gwh_2017                                                       0
# geolocation_source                                                      WRI
# gppd_idnr                                                        WRI1026814
# name                                                              Palo Seco
# other_fuel1                                                             NaN
# other_fuel2                                                             NaN
# other_fuel3                                                             NaN
# owner                                                                 PREPA
# primary_fuel                                                            Oil
# source                                                                PREPA
# url                                       http://www.prepa.com/PALOSECO.ASP
# wepp_id                                                               30942
# year_of_capacity_data                                                     0
# .geo                      {"type":"Point","coordinates":[-66.14859700475...
#
#                                                                           4
# system:index                                           00000000000000002def
# capacity_mw                                                              10
# commissioning_year                                                     1915
# country                                                                 USA
# country_long                                       United States of America
# estimated_generation_gwh                                            456.932
# generation_gwh_2013                                                       0
# generation_gwh_2014                                                       0
# generation_gwh_2015                                                       0
# generation_gwh_2016                                                       0
# generation_gwh_2017                                                       0
# geolocation_source                                                      WRI
# gppd_idnr                                                        WRI1026821
# name                                                               Carite 1
# other_fuel1                                                             NaN
# other_fuel2                                                             NaN
# other_fuel3                                                             NaN
# owner                                                                 PREPA
# primary_fuel                                                          Hydro
# source                                                                PREPA
# url                       http://www.prepa.com/historia_eng.asp  https:/...
# wepp_id                                                               65289
# year_of_capacity_data                                                     0
# .geo                      {"type":"Point","coordinates":[-66.10600367149...

# %%
lat_lng = df_power_plants[".geo"].apply(lambda x: pd.read_json(x)["coordinates"])
df_power_plants = df_power_plants.assign(lat=lat_lng[1],lng=lat_lng[0])

# %% [markdown]
# ## Remove irrelevants columns
#
#
# All columns with a single unique value are removed

# %%
remove_col = []
for colname,col_serie in df_power_plants.iteritems():
    if len(col_serie.unique())== 1:
        remove_col.append(colname)
        
df_power_plants.drop(columns=remove_col,inplace=True)
print("Removed columns: {}\n".format(", ".join(remove_col)))
print("Final columns: {}".format(", ".join(df_power_plants.columns)))
# Out:
# Removed columns: country, country_long, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, geolocation_source, other_fuel1, other_fuel2, other_fuel3, year_of_capacity_data
#
# Final columns: system:index, capacity_mw, commissioning_year, estimated_generation_gwh, gppd_idnr, name, owner, primary_fuel, source, url, wepp_id, .geo, lat, lng

# %% [markdown]
# ## Columns
#
# ### system:index
# Unique plant-level ID

# %%
df_power_plants.shape[0] == df_power_plants["system:index"].unique().shape[0]
# Out:
# True

# %%
df_power_plants["system:index"].unique().shape[0] == df_power_plants["system:index"].apply(lambda x: x[-3:]).unique().shape[0]
# Out:
# True

# %%
df_power_plants["name_id"] = df_power_plants["name"] + "_" + df_power_plants["system:index"].apply(lambda x: x[-3:])

# %%
df_power_plants["name"]
# Out:
# 0                  Dos Bocas
# 1                    Aguirre
# 2                  Costa Sur
# 3                  Palo Seco
# 4                   Carite 1
# 5               Toro Negro 1
# 6                   Garzas 1
# 7                   Garzas 2
# 8               Toro Negro 2
# 9      San Fermin Solar Farm
# 10                   Aguirre
# 11                   Yabucoa
# 12                 Costa Sur
# 13                    Daguao
# 14              EcoEléctrica
# 15                     Jobos
# 16                  Mayagüez
# 17                 Palo Seco
# 18                 Vega Baja
# 19               Vieques EPP
# 20                   Yauco 1
# 21               Caonillas 1
# 22               Caonillas 2
# 23                Cambalache
# 24                   Yauco 2
# 25                Río Blanco
# 26               AES Ilumina
# 27                   Salinas
# 28              A.E.S. Corp.
# 29             Windmar Ponce
# 30               San Juan CC
# 31                Punta Lima
# 32          Loiza Solar Park
# 33    Santa Isabel Wind Farm
# 34         Oriana Solar Farm
# Name: name, dtype: object

# %% [markdown]
# ### capacity_mw
#
# Electrical generating capacity in megawatts. Is the maximum electric output an electricity generator can produce under specific conditions. Nameplate generator capacity is determined by the generator's manufacturer and indicates the maximum output of electricity a generator can produce without exceeding design limits.

# %%
plt.figure(figsize=(8,7))
plt.title("Electrical generating capacity (MW) by plants")
df_power_plants.groupby(["name_id"]).mean()["capacity_mw"].sort_values().plot(kind="barh")
plt.tight_layout()

# %% [markdown]
# ## estimated_generation_gwh
#
# Estimated annual electricity generation in gigawatt-hours

# %%
plt.figure(figsize=(15,8))
ax = plt.subplot(1,2,1)
plt.title("Estimated annual electricity generation in gigawatt-hours")
df_power_plants.groupby(["name_id"]).mean()["estimated_generation_gwh"].sort_values().plot(kind="barh",ax=ax)

ax = plt.subplot(1,2,2)
plt.title("Electrical generating capacity (MW) by plants")
df_power_plants.groupby(["name_id"]).mean()["capacity_mw"].sort_values().plot(kind="barh",ax=ax)
plt.tight_layout()

# %% [markdown]
# ### Primary_fuel
#
# Energy source used in primary electricity generation or export

# %%
plt.figure(figsize=(15,5))
ax = plt.subplot(1,2,1)
df_power_plants.groupby(["primary_fuel"])[["capacity_mw"]].sum().sort_values(by="capacity_mw").plot(kind="barh",ax=ax);
plt.title("Electrical generating capacity (MW sum) by primary_fuel");

ax = plt.subplot(1,2,2)
df_power_plants.groupby(["primary_fuel"])[["name_id"]].count().sort_values(by="name_id", ascending=False).plot(kind="bar",ax=ax);
plt.title("Power Plants based on primary Fuel");

# %% [markdown]
# ### gppd_idnr
# 10- or 12-character identifier for the power plant

# %%
df_power_plants.shape[0] == df_power_plants["gppd_idnr"].unique().shape[0]
# Out:
# True

# %% [markdown]
# ### Commissioning_year
#
# Year of plant operation, weighted by unit-capacity when data is available

# %%
df_power_plants[["commissioning_year","capacity_mw"]].sort_values(by="commissioning_year").plot(kind="scatter",x="commissioning_year",y="capacity_mw",s=32)

# %% [markdown]
# ### Owner
#
# Majority shareholder of the power plant, generally in Romanized form

# %%
print(df_power_plants["owner"].unique())
df_power_plants.groupby("owner").count()["name_id"].sort_values()
# Out:
# ['PREPA' nan 'Gas Natural Fenosa  International Power' 'AES Corporation'
#  'Sonnedix' 'Windmar Renewable Energy' 'Sovereign Bank'
#  'Uriel Renewables and Coqui Power' 'Pattern Energy']
# owner
# Gas Natural Fenosa  International Power     1
# Pattern Energy                              1
# Sovereign Bank                              1
# Uriel Renewables and Coqui Power            1
# Windmar Renewable Energy                    1
# AES Corporation                             2
# Sonnedix                                    2
# PREPA                                      13
# Name: name_id, dtype: int64

# %%
plt.figure(figsize=(8,8))
df_power_plants.groupby("owner").sum()["estimated_generation_gwh"].sort_values(ascending=False).plot(kind="bar")
plt.tight_layout()

print("Estimated generation sum (GWH) by owner")
print(df_power_plants.groupby("owner").sum()["estimated_generation_gwh"]/df_power_plants["estimated_generation_gwh"].sum())
# Out:
# Estimated generation sum (GWH) by owner
# owner
# AES Corporation                            0.925466
# Gas Natural Fenosa  International Power    0.007337
# PREPA                                      0.053935
# Pattern Energy                             0.000037
# Sonnedix                                   0.000067
# Sovereign Bank                             0.000009
# Uriel Renewables and Coqui Power           0.000024
# Windmar Renewable Energy                   0.000004
# Name: estimated_generation_gwh, dtype: float64

# %%
df_power_plants.head()
# Out:
#            system:index  capacity_mw  commissioning_year  \
# 0  0000000000000000315a         15.0              1942.0
# 1  000000000000000026e5       1492.0              1975.0
# 2  00000000000000002fda        990.0              1962.0
# 3  00000000000000003f76        602.0              1960.0
# 4  00000000000000002def         10.0              1915.0
#
#    estimated_generation_gwh   gppd_idnr       name  owner primary_fuel source  \
# 0                685.397712  WRI1026827  Dos Bocas  PREPA        Hydro   CEPR
# 1               8334.010812  WRI1026809    Aguirre  PREPA          Oil  PREPA
# 2               5529.940150  WRI1026811  Costa Sur  PREPA          Oil  PREPA
# 3               3362.650475  WRI1026814  Palo Seco  PREPA          Oil  PREPA
# 4                456.931808  WRI1026821   Carite 1  PREPA        Hydro  PREPA
#
#                                                  url  wepp_id  \
# 0               http://energia.pr.gov/datos/plantas/  30936.0
# 1                   http://www.prepa.com/aguirre.asp  30928.0
# 2                  http://www.prepa.com/costasur.asp  30934.0
# 3                  http://www.prepa.com/PALOSECO.ASP  30942.0
# 4  http://www.prepa.com/historia_eng.asp  https:/...  65289.0
#
#                                                 .geo        lat        lng  \
# 0  {"type":"Point","coordinates":[-66.66629863706...  18.335899 -66.666299
# 1  {"type":"Point","coordinates":[-66.23079607357...  17.951899 -66.230796
# 2  {"type":"Point","coordinates":[-66.75340271704...  18.000298 -66.753403
# 3  {"type":"Point","coordinates":[-66.14859700475...  18.455301 -66.148597
# 4  {"type":"Point","coordinates":[-66.10600367149...  18.044702 -66.106004
#
#          name_id
# 0  Dos Bocas_15a
# 1    Aguirre_6e5
# 2  Costa Sur_fda
# 3  Palo Seco_f76
# 4   Carite 1_def

# %%
df_subset = df_power_plants[['name','lat','lng']]

# %%
df_subset.tail()
# Out:
#                       name        lat        lng
# 30             San Juan CC  18.426999 -66.104501
# 31              Punta Lima  18.186800 -65.694803
# 32        Loiza Solar Park  18.413399 -65.902802
# 33  Santa Isabel Wind Farm  17.985298 -66.398003
# 34       Oriana Solar Farm  18.472901 -67.044297

# %%
df_power_plants.to_csv('../data/df_power_plants.csv', index = False, header=True)

df_subset.to_csv('../data/df_subset.csv', index = False, header=True)

# %% [markdown]
# ### Geographical analysis

# %%
def addpoint(lat,lng,data,scale=10,var_circle="capacity_mw"):
    folium.Marker(
    location=[lat, lng],
    popup=pd.DataFrame(data).to_html(),
    icon=folium.Icon(icon='bolt',color='black',icon_color="yellow",prefix="fa")
    ).add_to(m)
    
    folium.CircleMarker(
    location=[lat, lng],
    radius=data[var_circle]/scale,
    color='red',
    fill=True,
    fill_color='red'
    ).add_to(m)
    
    
m = folium.Map(tiles="cartodbpositron",
    location=[18.245497, -66.524216],
            zoom_start=9)

df_power_plants.apply(lambda x: addpoint(x.lat,x.lng,x),axis=1 )
print("Capacity_mw")

m
# Out:
# Capacity_mw
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
 m = folium.Map(tiles="cartodbpositron",
    location=[18.245497, -66.524216],
            zoom_start=9)

df_power_plants.apply(lambda x: addpoint(x.lat,x.lng,x,1000,"estimated_generation_gwh"),axis=1 )
print("estimated_generation_gwh")

m
# Out:
# estimated_generation_gwh
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
